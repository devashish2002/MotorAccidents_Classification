# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('allFeat.csv')
data = data.iloc[:, 1:]
data.head()
# Out:
#    boro_ct201  complexity  NUMBER OF PERSONS INJURED  \
# 0     5000900    9.533045                        0.0
# 1     5000900    9.533045                        0.0
# 2     5000900    9.533045                        0.0
# 3     5000900    9.533045                        0.0
# 4     5000900    9.533045                        0.0
#
#    NUMBER OF PERSONS KILLED class1 class2 class3  dayOfWeek  time   st_width  \
# 0                       0.0  sedan  sedan    NaN          2    16  28.818182
# 1                       0.0    NaN    NaN    NaN          1    15  28.818182
# 2                       0.0    suv    NaN    NaN          0     9  28.818182
# 3                       0.0    NaN    NaN    NaN          6    13  28.818182
# 4                       0.0    NaN    suv    NaN          2    18  28.818182
#
#    bike_lane  outcome
# 0        7.0        0
# 1        7.0        0
# 2        7.0        0
# 3        7.0        0
# 4        7.0        0

# %%
data.describe()
# Out:
#          boro_ct201    complexity  NUMBER OF PERSONS INJURED  \
# count  1.310894e+06  1.309812e+06               1.310879e+06
# mean   2.825966e+06  4.599041e+01               2.602811e-01
# std    1.238090e+06  6.201235e+01               6.540714e-01
# min    1.000201e+06  1.999988e+00               0.000000e+00
# 25%    2.006500e+06  1.400008e+01               0.000000e+00
# 50%    3.037300e+06  2.416285e+01               0.000000e+00
# 75%    4.028300e+06  5.440521e+01               0.000000e+00
# max    5.032300e+06  7.112060e+02               4.300000e+01
#
#        NUMBER OF PERSONS KILLED     dayOfWeek          time      st_width  \
# count              1.310866e+06  1.310894e+06  1.310894e+06  1.310894e+06
# mean               1.142756e-03  2.904139e+00  1.331051e+01  3.447710e+01
# std                3.597252e-02  1.941877e+00  5.602130e+00  6.078169e+00
# min                0.000000e+00  0.000000e+00  0.000000e+00  1.107692e+01
# ...

# %%
sns.countplot(data.outcome)

# %%
data.complexity.mean()
# Out:
# 45.990407347438705
